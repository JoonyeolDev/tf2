# %%
# !dir #디렉터리 위치
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 6E9E-2841
#
#  C:\pythondata\03_ex 디렉터리
#
#
#  C:\pythondata\03_ex 디렉터리
# 파일을 찾을 수 없습니다.

# %%
pwd #작업 위치
# Out:
# 'C:\\pythondata\\03_ex'

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv',encoding='cp949')
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
pd.read_csv('주택도시보증공사_전국_평균_분양가격(2019년_12월).csv',encoding='cp949')
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 4330  제주                 전체  2019  12    3882
# 4331  제주         전용면적 60㎡이하  2019  12     NaN
# 4332  제주   전용면적 60㎡초과 85㎡이하  2019  12    3898
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601
#
# [4335 rows x 5 columns]

# %%
df_last = pd.read_csv('주택도시보증공사_전국_평균_분양가격(2019년_12월).csv',encoding='cp949') #오류가 뜰 수도 있음 engine = python 사용하면 없어짐
df_last.shape
# Out:
# (4335, 5)

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
df_last.tail()
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 4330  제주                 전체  2019  12    3882
# 4331  제주         전용면적 60㎡이하  2019  12     NaN
# 4332  제주   전용면적 60㎡초과 85㎡이하  2019  12    3898
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601

# %%
df_first = pd.read_csv('전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv',encoding='cp949')
df_first.shape
# Out:
# (17, 22)

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
df_last.isna().sum().sum() # NaN값이 계산에 지장을 주지 않는경우 미리 지울필욘없다
# Out:
# 277

# %%
#df_last.dropna(inplace=True)
pd.to_numeric(df_last['분양가격(㎡)'],errors='coerce').isna().sum()
#df_last['분양가격(㎡)'].astype('int')
# Out:
# 378

# %%
type(np.nan)
# Out:
# float

# %%
df_last['분양가격'] = pd.to_numeric(df_last['분양가격(㎡)'],errors='coerce')

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 203.3+ KB

# %%
df_last['분양가격'].mean()
# Out:
# 3238.128632802628

# %%
df_last['평당분양가격'] = df_last['분양가격']*3.3

# %%
df_last.sample(2)
# Out:
#      지역명              규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 2462  제주  전용면적 60㎡초과 85㎡이하  2018   2    3542  3542.0  11688.6
# 1250  전북                전체  2016  12    2004  2004.0   6613.2

# %%
df_last['분양가격(㎡)'].describe() #대표값 확인
# Out:
# count     4058
# unique    1753
# top       2221
# freq        17
# Name: 분양가격(㎡), dtype: object

# %%
df_last['평당분양가격'].describe()
# Out:
# count     3957.000000
# mean     10685.824488
# std       4172.222780
# min       6164.400000
# 25%       8055.300000
# 50%       9484.200000
# 75%      11751.300000
# max      42002.400000
# Name: 평당분양가격, dtype: float64

# %%
df_last.head(2)
# Out:
#   지역명        규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0  서울          전체  2015  10    5841  5841.0  19275.3
# 1  서울  전용면적 60㎡이하  2015  10    5652  5652.0  18651.6

# %%
df_last.규모구분.value_counts()
# Out:
# 전체                   867
# 전용면적 60㎡이하           867
# 전용면적 60㎡초과 85㎡이하     867
# 전용면적 85㎡초과 102㎡이하    867
# 전용면적 102㎡초과          867
# Name: 규모구분, dtype: int64

# %%
df_last.규모구분.unique()
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
# index1 = df_last[df_last['규모구분'] == '전체'].index
# index1
# #if df_last['규모구분'] == '전체':
# df_last=df_last.drop(index1)

df_last['규모구분'] = df_last['규모구분'].str.replace('전용면적','').str.replace('초과','~').str.replace('이하','').str.replace(' ','').str.strip()

# %%
df_last['규모구분']
# Out:
# 0             전체
# 1            60㎡
# 2        60㎡~85㎡
# 3       85㎡~102㎡
# 4          102㎡~
#           ...
# 4330          전체
# 4331         60㎡
# 4332     60㎡~85㎡
# 4333    85㎡~102㎡
# 4334       102㎡~
# Name: 규모구분, Length: 4335, dtype: object

# %%
df_last.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격'], dtype='object')

# %%
# 규모구분 > 전용면적, 분양가격제거 
df_last.colums = ['지역명', '전용면적', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격']

# %%
df_last.drop('분양가격(㎡)', axis=1) #df_last.drop('분양가격(㎡)', inplace=True)
# Out:
#      지역명      규모구분    연도   월    분양가격   평당분양가격
# 0     서울        전체  2015  10  5841.0  19275.3
# 1     서울       60㎡  2015  10  5652.0  18651.6
# 2     서울   60㎡~85㎡  2015  10  5882.0  19410.6
# 3     서울  85㎡~102㎡  2015  10  5721.0  18879.3
# 4     서울     102㎡~  2015  10  5879.0  19400.7
# ...   ..       ...   ...  ..     ...      ...
# 4330  제주        전체  2019  12  3882.0  12810.6
# 4331  제주       60㎡  2019  12     NaN      NaN
# 4332  제주   60㎡~85㎡  2019  12  3898.0  12863.4
# 4333  제주  85㎡~102㎡  2019  12     NaN      NaN
# 4334  제주     102㎡~  2019  12  3601.0  11883.3
#
# [4335 rows x 6 columns]

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당분양가격   3957 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 237.2+ KB

# %%
df_last.groupby(['지역명'])['평당분양가격'].mean().to_frame()#.sort_values('평당분양가격').plot(kind='barh')
# groupby 컬럼이 하나일때는 대괄호가 없어도 된다
# Out:
#            평당분양가격
# 지역명
# 강원    7890.750000
# 경기   13356.895200
# 경남    9268.778138
# 경북    8376.536515
# 광주    9951.535821
# 대구   11980.895455
# 대전   10253.333333
# 부산   12087.121200
# 서울   23599.976400
# 세종    9796.516456
# 울산   10014.902013
# 인천   11915.320732
# 전남    7565.316532
# 전북    7724.235484
# 제주   11241.276712
# 충남    8233.651883
# 충북    7634.655600

# %%
df_last.groupby(['지역명'])['평당분양가격'].mean().to_frame().sort_values('평당분양가격').plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='지역명'>

# %%
# df_last[df_last['전용면적']!='전체'] 사용해서 '전체'항목을 없애도 된다

# %%
# 전용면적, 지역별 평단분양가격

# %%
# 1. 전용면적별 평단분양가격

df_last.groupby(['규모구분','지역명'])['평당분양가격'].mean().to_frame().reset_index() #unstack()
# Out:
#      규모구분 지역명        평당분양가격
# 0   102㎡~  강원   8311.380000
# 1   102㎡~  경기  14771.790000
# 2   102㎡~  경남  10358.363265
# 3   102㎡~  경북   9157.302000
# 4   102㎡~  광주  11041.532432
# ..    ...  ..           ...
# 80     전체  전남   7283.562000
# 81     전체  전북   7292.604000
# 82     전체  제주  10784.994000
# 83     전체  충남   7815.324000
# 84     전체  충북   7219.014000
#
# [85 rows x 3 columns]

# %%
g = df_last.groupby(['규모구분','지역명'])['평당분양가격'].mean().to_frame()

# %%
g.unstack().T
# Out:
# 규모구분               102㎡~           60㎡       60㎡~85㎡      85㎡~102㎡  \
#        지역명
# 평당분양가격 강원    8311.380000   7567.098000   7485.588000   8749.557143
#        경기   14771.790000  13251.744000  12523.566000  13677.774000
#        경남   10358.363265   8689.175000   8618.676000  10017.612000
#        경북    9157.302000   7883.172000   8061.372000   8773.814634
#        광주   11041.532432   9430.666667   9910.692000   9296.100000
#        대구   13087.338000  11992.068000  11778.690000  11140.642857
#        대전   14876.871429   9176.475000   9711.372000   9037.430769
#        부산   13208.250000  11353.782000  11864.820000  12072.588000
#        서울   23446.038000  23212.794000  22786.830000  25943.874000
#        세종   10106.976000   9323.927027   9775.458000   9847.926000
#        울산    9974.448000   9202.106897  10502.531707   8861.007692
#        인천   14362.030435  11241.318000  11384.406000  11527.560000
#        전남    8168.490000   7210.170000   7269.240000   7908.862500
# ...

# %%
pd.pivot_table(df_last,index=['지역명'],values=['평당분양가격'])
# df_last.groupby(['지역명'])['평당분양가격'].mean() 결과가 같은 코드
# Out:
#            평당분양가격
# 지역명
# 강원    7890.750000
# 경기   13356.895200
# 경남    9268.778138
# 경북    8376.536515
# 광주    9951.535821
# 대구   11980.895455
# 대전   10253.333333
# 부산   12087.121200
# 서울   23599.976400
# 세종    9796.516456
# 울산   10014.902013
# 인천   11915.320732
# 전남    7565.316532
# 전북    7724.235484
# 제주   11241.276712
# 충남    8233.651883
# 충북    7634.655600

# %%
pd.pivot_table(df_last,index=['지역명'],values=['평당분양가격'], columns=['규모구분']).round() # round() 반올림
# Out:
#        평당분양가격
# 규모구분    102㎡~      60㎡  60㎡~85㎡ 85㎡~102㎡       전체
# 지역명
# 강원     8311.0   7567.0   7486.0   8750.0   7478.0
# 경기    14772.0  13252.0  12524.0  13678.0  12560.0
# 경남    10358.0   8689.0   8619.0  10018.0   8659.0
# 경북     9157.0   7883.0   8061.0   8774.0   8079.0
# 광주    11042.0   9431.0   9911.0   9296.0   9904.0
# 대구    13087.0  11992.0  11779.0  11141.0  11771.0
# 대전    14877.0   9176.0   9711.0   9037.0   9786.0
# 부산    13208.0  11354.0  11865.0  12073.0  11936.0
# 서울    23446.0  23213.0  22787.0  25944.0  22610.0
# 세종    10107.0   9324.0   9775.0   9848.0   9805.0
# 울산     9974.0   9202.0  10503.0   8861.0  10493.0
# 인천    14362.0  11241.0  11384.0  11528.0  11257.0
# 전남     8168.0   7210.0   7269.0   7909.0   7284.0
# 전북     8194.0   7610.0   7271.0   8276.0   7293.0
# 제주    10523.0  14022.0  10621.0  10709.0  10785.0
# 충남     8689.0   7911.0   7819.0   9120.0   7815.0
# 충북     8195.0   7103.0   7264.0   8391.0   7219.0

# %%
result = pd.pivot_table(df_last, index=['지역명'], values=['평당분양가격']).round()

# %%
result.plot(kind='box') # box는 이상치가 있는지 확인하기 위한 용도로 사용할 수 있다
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df_last, index='월',columns='연도', values='평당분양가격').plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df_last, index='지역명',columns='연도', values='평당분양가격').plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df_last, index='연도',columns='지역명', values='평당분양가격').plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# pandas plot은 데이터 처리가 다 된 상태에서 편함
# seaborn은 여러가지 plot을 사용해 시각화하여 다양한 정보를 보여줌

import seaborn as sns
sns.barplot(data=df_last,x='지역명', y='평당분양가격')
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
sns.barplot(data=df_last,x='연도', y='평당분양가격')
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.barplot(data=df_last,x='지역명',hue='연도', y='평당분양가격')
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
sns.catplot(data=df_last,x='연도',y='평당분양가격',kind='bar',col='지역명',col_wrap=4)

# %%
sns.relplot(data=df_last,x='연도',y='평당분양가격',kind='line',col='지역명',col_wrap=4)

# %%
# violins box plot의 한계를 보완해주는 plot

# %%
pd.read_csv('전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv', encoding='cp949')
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
pd.options.display.max_columns =25 # 표기 컬럼수 설정

# %%
pd.read_csv('전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv', encoding='cp949')
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
df_first
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
# 지역명 연도 월 값

df_first1=df_first.melt(id_vars='지역', var_name='기간', value_name='평당분양가격') #data에서 그대로 유지할 컬럼을 적어준다

# %%
df_first1
# Out:
#      지역  평당분양가격    연도   월
# 0    서울   18189  2013  12
# 1    부산    8111  2013  12
# 2    대구    8080  2013  12
# 3    인천   10204  2013  12
# 4    광주    6098  2013  12
# ..   ..     ...   ...  ..
# 352  전북    6580  2015   8
# 353  전남    6289  2015   8
# 354  경북    7037  2015   8
# 355  경남    7665  2015   8
# 356  제주    7343  2015   8
#
# [357 rows x 4 columns]

# %%
fire = pd.read_csv('전라북도_소방서별 소방자동차 현황_20170810..csv', encoding='cp949')

# %%
fire.melt(id_vars='시군') #NaN이 실수취급이기때문에 float으로 정리
# Out:
#       시군   variable  value
# 0     본부  고가차 53(m)    NaN
# 1     덕진  고가차 53(m)    1.0
# 2     완산  고가차 53(m)    NaN
# 3     군산  고가차 53(m)    NaN
# 4     익산  고가차 53(m)    1.0
# ..   ...        ...    ...
# 369   남원      버   스    NaN
# 370   김제      버   스    NaN
# 371   고창      버   스    NaN
# 372   부안      버   스    NaN
# 373  무진장      버   스    NaN
#
# [374 rows x 3 columns]

# %%
# 기간을 년도 + 월 정수형태로 분리

df_first1['연도'] = df_first1['기간'].str.split('년').str.get(0).astype('int')
df_first1['월'] = df_first1['기간'].str.split('년').str.get(1).str.split('월').str.get(0).astype('int')

# %%
df_first1.drop(columns='기간',inplace=True)

# %%
df_first1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      357 non-null    object
#  1   평당분양가격  357 non-null    int64
#  2   연도      357 non-null    int32
#  3   월       357 non-null    int32
# dtypes: int32(2), int64(1), object(1)
# memory usage: 8.5+ KB

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당분양가격   3957 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 237.2+ KB

# %%
# pd.concat(df_first1,df_last)

df1 = df_first1[['지역','연도','월','평당분양가격']]
df1
# Out:
#      지역    연도   월  평당분양가격
# 0    서울  2013  12   18189
# 1    부산  2013  12    8111
# 2    대구  2013  12    8080
# 3    인천  2013  12   10204
# 4    광주  2013  12    6098
# ..   ..   ...  ..     ...
# 352  전북  2015   8    6580
# 353  전남  2015   8    6289
# 354  경북  2015   8    7037
# 355  경남  2015   8    7665
# 356  제주  2015   8    7343
#
# [357 rows x 4 columns]

# %%
df2 = df_last[['지역명','연도','월','평당분양가격']]

# %%
df2.columns = ['지역','연도','월','평당분양가격']
df2
# Out:
#       지역    연도   월   평당분양가격
# 0     서울  2015  10  19275.3
# 1     서울  2015  10  18651.6
# 2     서울  2015  10  19410.6
# 3     서울  2015  10  18879.3
# 4     서울  2015  10  19400.7
# ...   ..   ...  ..      ...
# 4330  제주  2019  12  12810.6
# 4331  제주  2019  12      NaN
# 4332  제주  2019  12  12863.4
# 4333  제주  2019  12      NaN
# 4334  제주  2019  12  11883.3
#
# [4335 rows x 4 columns]

# %%
df = pd.concat([df1,df2],axis=0)

# %%
df
# Out:
#       지역    연도   월   평당분양가격
# 0     서울  2013  12  18189.0
# 1     부산  2013  12   8111.0
# 2     대구  2013  12   8080.0
# 3     인천  2013  12  10204.0
# 4     광주  2013  12   6098.0
# ...   ..   ...  ..      ...
# 4330  제주  2019  12  12810.6
# 4331  제주  2019  12      NaN
# 4332  제주  2019  12  12863.4
# 4333  제주  2019  12      NaN
# 4334  제주  2019  12  11883.3
#
# [4692 rows x 4 columns]

# %%
sns.barplot(data=df,'지역','평당분양가격')
# Out:
#   Input In [68]
#     sns.barplot(data=df,'지역','평당분양가격')
#                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
d2 = pd.read_csv('survey_site.csv', encoding='cp949')
d1 = pd.read_csv('survey_visited.csv', encoding='cp949')

# %%
d1

# %%
d2

# %%
pd.merge(d1,d2,left_on='site',right_on='name',how='outer') 
#inner join key 값이 있는거끼리 가져옴, 왼쪽에만있거나 오른쪽에만 있는값은 빠짐 left > d1, right > d2, outer > 둘다
